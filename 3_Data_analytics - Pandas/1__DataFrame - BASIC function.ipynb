# %%
import pandas as pd

# %%
"Hello_dear"
# Out:
# 'Hello_dear'

# %%
[1,2.4,'Ramar']
# Out:
# [1, 2.4, 'Ramar']

# %%
# Reading an "csv-file" by file-path

pd.read_csv("E:/DATA Science - My preparation/3_Data_analytics - Pandas/Data-files/Pandas - Q1 Sales.csv")
# Out:
#       Country Region Sales Person    Date of Purchase     Total  Quantity
# 0       India  North         John    4/4/2018 0:00:00    100000       567
# 1          US  North         Bill  12/11/2017 0:00:00    120000      3000
# 2          UK  North       Thomas   5/12/2016 0:00:00    140000       345
# 3   Australia   East         John   6/20/2011 0:00:00    160000      1000
# 4      Africa   East         Bill   4/12/2011 0:00:00    180000       123
# 5   Singapore   East       Thomas    7/5/2014 0:00:00    200000      1000
# 6     Mylasia   West         John   8/15/2015 0:00:00   1000000      7890
# 7       India   West         Bill  11/19/2015 0:00:00    240000       200
# 8          US   West       Thomas   8/29/2017 0:00:00  26000000      1000
# 9          UK  North         John   5/10/2018 0:00:00    100000      1000
# 10  Australia  North         Bill   12/9/2016 0:00:00    120000       567
# 11     Africa  North       Thomas    7/4/2018 0:00:00    140000      1000
# ...

# %%
# Provides Documentation about "read_csv"

print(pd.read_csv.__doc__)
# Out:
# Read a comma-separated values (csv) file into DataFrame.
#
# Also supports optionally iterating or breaking of the file
# into chunks.
#
# Additional help can be found in the online docs for
# `IO Tools <https://pandas.pydata.org/pandas-docs/stable/user_guide/io.html>`_.
#
# Parameters
# ----------
# filepath_or_buffer : str, path object or file-like object
#     Any valid string path is acceptable. The string could be a URL. Valid
#     URL schemes include http, ftp, s3, gs, and file. For file URLs, a host is
#     expected. A local file could be: file://localhost/path/to/table.csv.
#
#     If you want to pass in a path object, pandas accepts any ``os.PathLike``.
#
#     By file-like object, we refer to objects with a ``read()`` method, such as
#     a file handle (e.g. via builtin ``open`` function) or ``StringIO``.
# sep : str, default ','
#     Delimiter to use. If sep is None, the C engine cannot automatically detect
# ...

# %%
# Provides Documentation about "read_sql_table"

print(pd.read_sql_table.__doc__)
# Out:
#     Read SQL database table into a DataFrame.
#
#     Given a table name and a SQLAlchemy connectable, returns a DataFrame.
#     This function does not support DBAPI connections.
#
#     Parameters
#     ----------
#     table_name : str
#         Name of SQL table in database.
#     con : SQLAlchemy connectable or str
#         A database URI could be provided as str.
#         SQLite DBAPI connection mode not supported.
#     schema : str, default None
#         Name of SQL schema in database to query (if database flavor
#         supports this). Uses default schema if None (default).
#     index_col : str or list of str, optional, default: None
#         Column(s) to set as index(MultiIndex).
#     coerce_float : bool, default True
#         Attempts to convert values of non-string, non-numeric objects (like
#         decimal.Decimal) to floating point. Can result in loss of Precision.
#     parse_dates : list or dict, default None
# ...

# %%
# Reading of CSV-file content is stored into "Data_frame = df"

df = pd.read_csv("E:/DATA Science - My preparation/3_Data_analytics - Pandas/Data-files/Pandas - Q1 Sales.csv")
df
# Out:
#       Country Region Sales Person    Date of Purchase     Total  Quantity
# 0       India  North         John    4/4/2018 0:00:00    100000       567
# 1          US  North         Bill  12/11/2017 0:00:00    120000      3000
# 2          UK  North       Thomas   5/12/2016 0:00:00    140000       345
# 3   Australia   East         John   6/20/2011 0:00:00    160000      1000
# 4      Africa   East         Bill   4/12/2011 0:00:00    180000       123
# 5   Singapore   East       Thomas    7/5/2014 0:00:00    200000      1000
# 6     Mylasia   West         John   8/15/2015 0:00:00   1000000      7890
# 7       India   West         Bill  11/19/2015 0:00:00    240000       200
# 8          US   West       Thomas   8/29/2017 0:00:00  26000000      1000
# 9          UK  North         John   5/10/2018 0:00:00    100000      1000
# 10  Australia  North         Bill   12/9/2016 0:00:00    120000       567
# 11     Africa  North       Thomas    7/4/2018 0:00:00    140000      1000
# ...

# %%
# Used to show (rows,column)

df.shape
# Out:
# (20, 6)

# %%
# Displays 1st five records by default

df.head()
# Out:
#      Country Region Sales Person    Date of Purchase   Total  Quantity
# 0      India  North         John    4/4/2018 0:00:00  100000       567
# 1         US  North         Bill  12/11/2017 0:00:00  120000      3000
# 2         UK  North       Thomas   5/12/2016 0:00:00  140000       345
# 3  Australia   East         John   6/20/2011 0:00:00  160000      1000
# 4     Africa   East         Bill   4/12/2011 0:00:00  180000       123

# %%
# Displays first - 10 number of records from head(Begin)
df.head(10)
# Out:
#      Country Region Sales Person    Date of Purchase     Total  Quantity
# 0      India  North         John    4/4/2018 0:00:00    100000       567
# 1         US  North         Bill  12/11/2017 0:00:00    120000      3000
# 2         UK  North       Thomas   5/12/2016 0:00:00    140000       345
# 3  Australia   East         John   6/20/2011 0:00:00    160000      1000
# 4     Africa   East         Bill   4/12/2011 0:00:00    180000       123
# 5  Singapore   East       Thomas    7/5/2014 0:00:00    200000      1000
# 6    Mylasia   West         John   8/15/2015 0:00:00   1000000      7890
# 7      India   West         Bill  11/19/2015 0:00:00    240000       200
# 8         US   West       Thomas   8/29/2017 0:00:00  26000000      1000
# 9         UK  North         John   5/10/2018 0:00:00    100000      1000

# %%
# Displays last five records by default

df.tail()
# Out:
#       Country Region Sales Person   Date of Purchase   Total  Quantity
# 15         US   West         John  1/24/2013 0:00:00  220000        90
# 16         UK   West         Bill   1/6/2017 0:00:00  240000        90
# 17  Australia   West       Thomas  8/28/2010 0:00:00  260000        90
# 18     Africa  North         John  6/20/2014 0:00:00  140000        85
# 19  Singapore  North         Bill  1/29/2014 0:00:00  150000        85

# %%
# Displays last - 10 number of records from Tail(End)

df.tail(10)
# Out:
#       Country Region Sales Person   Date of Purchase   Total  Quantity
# 10  Australia  North         Bill  12/9/2016 0:00:00  120000       567
# 11     Africa  North       Thomas   7/4/2018 0:00:00  140000      1000
# 12  Singapore   East         John  9/15/2017 0:00:00  160000       892
# 13    Mylasia   East         Bill   9/2/2011 0:00:00  180000       444
# 14      India   East       Thomas  10/5/2014 0:00:00  200000        90
# 15         US   West         John  1/24/2013 0:00:00  220000        90
# 16         UK   West         Bill   1/6/2017 0:00:00  240000        90
# 17  Australia   West       Thomas  8/28/2010 0:00:00  260000        90
# 18     Africa  North         John  6/20/2014 0:00:00  140000        85
# 19  Singapore  North         Bill  1/29/2014 0:00:00  150000        85

# %%
# Displays all - Numerical contents of df(dataframe)

df.describe()
# Out:
#               Total     Quantity
# count  2.000000e+01    20.000000
# mean   1.502500e+06   977.900000
# std    5.769280e+06  1761.923497
# min    1.000000e+05    85.000000
# 25%    1.400000e+05    90.000000
# 50%    1.700000e+05   505.500000
# 75%    2.250000e+05  1000.000000
# max    2.600000e+07  7890.000000

# %%
df['Country','Region']

#It throws error
# REASON :  **While using multiple key/column name use it in "list=[]" **
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Country', 'Region')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
#Accessing Multiple column within list[] - CORRECT
 
df[['Country','Region']]
# Out:
#       Country Region
# 0       India  North
# 1          US  North
# 2          UK  North
# 3   Australia   East
# 4      Africa   East
# 5   Singapore   East
# 6     Mylasia   West
# 7       India   West
# 8          US   West
# 9          UK  North
# 10  Australia  North
# 11     Africa  North
# 12  Singapore   East
# 13    Mylasia   East
# 14      India   East
# 15         US   West
# 16         UK   West
# 17  Australia   West
# 18     Africa  North
# 19  Singapore  North

# %%
# You can name an list=selective_columns & pass into df[selective_columns] which displays only selective columns

selective_columns = ['Country','Region','Total']
df[selective_columns]
# Out:
#       Country Region     Total
# 0       India  North    100000
# 1          US  North    120000
# 2          UK  North    140000
# 3   Australia   East    160000
# 4      Africa   East    180000
# 5   Singapore   East    200000
# 6     Mylasia   West   1000000
# 7       India   West    240000
# 8          US   West  26000000
# 9          UK  North    100000
# 10  Australia  North    120000
# 11     Africa  North    140000
# 12  Singapore   East    160000
# 13    Mylasia   East    180000
# 14      India   East    200000
# 15         US   West    220000
# 16         UK   West    240000
# 17  Australia   West    260000
# 18     Africa  North    140000
# 19  Singapore  North    150000

# %%
# Also You can clip df as  head() || tail()

df[selective_columns].head()
# Out:
#      Country Region   Total
# 0      India  North  100000
# 1         US  North  120000
# 2         UK  North  140000
# 3  Australia   East  160000
# 4     Africa   East  180000

# %%
df
# Out:
#       Country Region Sales Person    Date of Purchase     Total  Quantity
# 0       India  North         John    4/4/2018 0:00:00    100000       567
# 1          US  North         Bill  12/11/2017 0:00:00    120000      3000
# 2          UK  North       Thomas   5/12/2016 0:00:00    140000       345
# 3   Australia   East         John   6/20/2011 0:00:00    160000      1000
# 4      Africa   East         Bill   4/12/2011 0:00:00    180000       123
# 5   Singapore   East       Thomas    7/5/2014 0:00:00    200000      1000
# 6     Mylasia   West         John   8/15/2015 0:00:00   1000000      7890
# 7       India   West         Bill  11/19/2015 0:00:00    240000       200
# 8          US   West       Thomas   8/29/2017 0:00:00  26000000      1000
# 9          UK  North         John   5/10/2018 0:00:00    100000      1000
# 10  Australia  North         Bill   12/9/2016 0:00:00    120000       567
# 11     Africa  North       Thomas    7/4/2018 0:00:00    140000      1000
# ...

# %%
# Displays the three-rows using "iloc - index_position"

df.iloc[0:3]
# Out:
#   Country Region Sales Person    Date of Purchase   Total  Quantity
# 0   India  North         John    4/4/2018 0:00:00  100000       567
# 1      US  North         Bill  12/11/2017 0:00:00  120000      3000
# 2      UK  North       Thomas   5/12/2016 0:00:00  140000       345

# %%
# Displays Even rows , 4-columns

df.iloc[::2,:4]
# Out:
#       Country Region Sales Person   Date of Purchase
# 2          UK  North       Thomas  5/12/2016 0:00:00
# 4      Africa   East         Bill  4/12/2011 0:00:00
# 6     Mylasia   West         John  8/15/2015 0:00:00
# 8          US   West       Thomas  8/29/2017 0:00:00
# 10  Australia  North         Bill  12/9/2016 0:00:00
# 12  Singapore   East         John  9/15/2017 0:00:00
# 14      India   East       Thomas  10/5/2014 0:00:00
# 16         UK   West         Bill   1/6/2017 0:00:00
# 18     Africa  North         John  6/20/2014 0:00:00

# %%
# Display All-rows, selective columns using "loc - index/column_name"

df.loc[:, ["Country","Sales Person"]]
# Out:
#       Country Sales Person
# 0       India         John
# 1          US         Bill
# 2          UK       Thomas
# 3   Australia         John
# 4      Africa         Bill
# 5   Singapore       Thomas
# 6     Mylasia         John
# 7       India         Bill
# 8          US       Thomas
# 9          UK         John
# 10  Australia         Bill
# 11     Africa       Thomas
# 12  Singapore         John
# 13    Mylasia         Bill
# 14      India       Thomas
# 15         US         John
# 16         UK         Bill
# 17  Australia       Thomas
# 18     Africa         John
# 19  Singapore         Bill

# %%
# Display odd-rows, selective columns using "loc - index/column_name"

df.loc[1::2, ["Country","Sales Person"]]
# Out:
#       Country Sales Person
# 1          US         Bill
# 3   Australia         John
# 5   Singapore       Thomas
# 7       India         Bill
# 9          UK         John
# 11     Africa       Thomas
# 13    Mylasia         Bill
# 15         US         John
# 17  Australia       Thomas
# 19  Singapore         Bill

# %%
#Display entire dataftrame
df
# Out:
#       Country Region Sales Person    Date of Purchase     Total  Quantity
# 0       India  North         John    4/4/2018 0:00:00    100000       567
# 1          US  North         Bill  12/11/2017 0:00:00    120000      3000
# 2          UK  North       Thomas   5/12/2016 0:00:00    140000       345
# 3   Australia   East         John   6/20/2011 0:00:00    160000      1000
# 4      Africa   East         Bill   4/12/2011 0:00:00    180000       123
# 5   Singapore   East       Thomas    7/5/2014 0:00:00    200000      1000
# 6     Mylasia   West         John   8/15/2015 0:00:00   1000000      7890
# 7       India   West         Bill  11/19/2015 0:00:00    240000       200
# 8          US   West       Thomas   8/29/2017 0:00:00  26000000      1000
# 9          UK  North         John   5/10/2018 0:00:00    100000      1000
# 10  Australia  North         Bill   12/9/2016 0:00:00    120000       567
# 11     Africa  North       Thomas    7/4/2018 0:00:00    140000      1000
# ...

# %%
# Df of column="Country" which matches India alone displayed

df[df['Country']=='India']
# Out:
#    Country Region Sales Person    Date of Purchase   Total  Quantity
# 0    India  North         John    4/4/2018 0:00:00  100000       567
# 7    India   West         Bill  11/19/2015 0:00:00  240000       200
# 14   India   East       Thomas   10/5/2014 0:00:00  200000        90

# %%
#Df which matches those 2-condition will displayed 
# 1.country = US 
#      and
# 2.Region = West

df[(df['Country']=='US')  &  (df['Region']=='West')]
# Out:
#    Country Region Sales Person   Date of Purchase     Total  Quantity
# 8       US   West       Thomas  8/29/2017 0:00:00  26000000      1000
# 15      US   West         John  1/24/2013 0:00:00    220000        90

# %%
# Displays "all - Column_name" from csv.table

df.columns
# Out:
# Index(['Country', 'Region', 'Sales Person', 'Date of Purchase', 'Total',
#        'Quantity'],
#       dtype='object')
